# %%
import pandas as pd

# %% [markdown]
# # Rental data

# %%
all_inven = pd.read_csv("rentals/All/rentalInventory_All.csv")
OneBd = pd.read_csv("rentals/OneBd/rentalInventory_OneBd.csv")
Studio = pd.read_csv("rentals/Studio/rentalInventory_Studio.csv")
ThreePlusBd = pd.read_csv("rentals/ThreePlusBd/rentalInventory_ThreePlusBd.csv")
TwoBd = pd.read_csv("rentals/TwoBd/rentalInventory_TwoBd.csv")

all_inven = all_inven[['areaName','Borough','areaType','2018-10']].rename(columns = {'2018-10':'All'})
OneBd = OneBd[['areaName','Borough','areaType','2018-10']].rename(columns = {'2018-10':'OneBd'})
Studio = Studio[['areaName','Borough','areaType','2018-10']].rename(columns = {'2018-10':'Studio'})
ThreePlusBd = ThreePlusBd[['areaName','Borough','areaType','2018-10']].rename(columns = {'2018-10':'ThreePlusBd'})
TwoBd = TwoBd[['areaName','Borough','areaType','2018-10']].rename(columns = {'2018-10':'TwoBd'})

inventory = pd.merge(all_inven,OneBd,on = ['areaName','Borough','areaType'])
inventory = pd.merge(inventory,Studio,on = ['areaName','Borough','areaType'])
inventory = pd.merge(inventory,TwoBd,on = ['areaName','Borough','areaType'])
inventory = pd.merge(inventory,ThreePlusBd,on = ['areaName','Borough','areaType'])
inventory
# Out:
#                 areaName        Borough      areaType    All   OneBd  Studio  \
# 0           All Downtown      Manhattan     submarket   5877  2134.0  1287.0
# 1            All Midtown      Manhattan     submarket   4725  1889.0  1067.0
# 2    All Upper East Side      Manhattan     submarket   3006  1215.0   629.0
# 3    All Upper Manhattan      Manhattan     submarket   3268  1044.0   285.0
# 4    All Upper West Side      Manhattan     submarket   2636  1062.0   504.0
# 5             Alley Park         Queens  neighborhood      0     NaN     NaN
# 6                Astoria         Queens  neighborhood   1903   802.0   106.0
# 7             Auburndale         Queens  neighborhood     20     9.0     1.0
# 8             Bath Beach       Brooklyn  neighborhood     67    24.0     1.0
# 9      Battery Park City      Manhattan  neighborhood    213    82.0    29.0
# 10             Bay Ridge       Brooklyn  neighborhood    601   196.0    57.0
# 11            Baychester          Bronx  neighborhood      0     NaN     NaN
# 12               Bayside         Queens  neighborhood     27     6.0     4.0
# 13          Bedford Park          Bronx  neighborhood     14     4.0     1.0
# 14    Bedford-Stuyvesant       Brooklyn  neighborhood   2325   544.0    92.0
# 15             Bellerose         Queens  neighborhood      2     NaN     NaN
# 16               Belmont          Bronx  neighborhood     35     5.0     NaN
# 17           Bensonhurst       Brooklyn  neighborhood    121    51.0     7.0
# 18          Bergen Beach       Brooklyn  neighborhood     14     3.0     NaN
# 19           Boerum Hill       Brooklyn  neighborhood    113    43.0     5.0
# 20          Borough Park       Brooklyn  neighborhood     84    28.0     8.0
# 21            Bowne Park         Queens  neighborhood      0     NaN     NaN
# 22             Briarwood         Queens  neighborhood     71    36.0     6.0
# 23        Brighton Beach       Brooklyn  neighborhood     73    36.0     4.0
# 24                 Bronx          Bronx       borough   1154   404.0    91.0
# 25             Bronxwood          Bronx  neighborhood     17    13.0     NaN
# 26              Brooklyn       Brooklyn       borough  17556  5022.0  1277.0
# 27      Brooklyn Heights       Brooklyn  neighborhood    207    66.0    55.0
# 28            Brookville         Queens  neighborhood      1     NaN     NaN
# 29           Brownsville       Brooklyn  neighborhood     50    11.0     2.0
# ..                   ...            ...           ...    ...     ...     ...
# 172         South Queens         Queens     submarket    157    41.0    29.0
# 173  South Richmond Hill         Queens  neighborhood      3     NaN     1.0
# 174  Springfield Gardens         Queens  neighborhood      5     1.0     NaN
# 175           St. Albans         Queens  neighborhood      5     2.0     NaN
# 176        Staten Island  Staten Island       borough     97    36.0    11.0
# 177  Stuyvesant Town/PCV      Manhattan  neighborhood    101    20.0     NaN
# 178            Sunnyside         Queens  neighborhood    309   172.0    31.0
# 179          Sunset Park       Brooklyn  neighborhood    225    61.0     9.0
# 180        The Rockaways         Queens     submarket     89    30.0    13.0
# 181          Throgs Neck          Bronx  neighborhood     15     3.0     1.0
# 182              Tremont          Bronx  neighborhood     36     7.0     5.0
# 183              Tribeca      Manhattan  neighborhood    296    86.0    41.0
# 184   University Heights          Bronx  neighborhood     41    17.0     3.0
# 185      Upper East Side      Manhattan  neighborhood   3006  1215.0   629.0
# 186      Upper West Side      Manhattan  neighborhood   2636  1062.0   504.0
# 187               Utopia         Queens  neighborhood      3     NaN     NaN
# 188             Van Nest          Bronx  neighborhood      8     6.0     1.0
# 189            Wakefield          Bronx  neighborhood     13     5.0     NaN
# 190   Washington Heights      Manhattan  neighborhood    896   257.0    68.0
# 191          West Harlem      Manhattan  neighborhood     81    16.0     1.0
# 192         West Village      Manhattan  neighborhood    532   222.0   143.0
# 193  Westchester Village          Bronx  neighborhood      2     1.0     NaN
# 194           Whitestone         Queens  neighborhood     17     6.0     NaN
# 195       Williamsbridge          Bronx  neighborhood     20     5.0     1.0
# 196         Williamsburg       Brooklyn  neighborhood   3244   959.0   186.0
# 197      Windsor Terrace       Brooklyn  neighborhood    118    35.0     5.0
# 198            Woodhaven         Queens  neighborhood     15     6.0     NaN
# 199             Woodlawn          Bronx  neighborhood      4     3.0     NaN
# 200             Woodside         Queens  neighborhood    125    68.0    13.0
# 201            Woodstock          Bronx  neighborhood     20     6.0     NaN
#
#       TwoBd  ThreePlusBd
# 0    1613.0        843.0
# 1    1282.0        487.0
# 2     797.0        365.0
# 3    1087.0        852.0
# 4     644.0        426.0
# 5       NaN          NaN
# 6     720.0        275.0
# 7       8.0          2.0
# 8      25.0         17.0
# 9      71.0         31.0
# 10    227.0        121.0
# 11      NaN          NaN
# 12      8.0          9.0
# 13      3.0          6.0
# 14    869.0        820.0
# 15      NaN          2.0
# 16     11.0         19.0
# 17     31.0         32.0
# 18      5.0          6.0
# 19     42.0         23.0
# 20     35.0         13.0
# 21      NaN          NaN
# 22     25.0          4.0
# 23     24.0          9.0
# 24    367.0        292.0
# 25      4.0          NaN
# 26   6381.0       4876.0
# 27     55.0         31.0
# 28      NaN          1.0
# 29     16.0         21.0
# ..      ...          ...
# 172    45.0         42.0
# 173     NaN          2.0
# 174     4.0          NaN
# 175     1.0          2.0
# 176    25.0         25.0
# 177    45.0         36.0
# 178    90.0         16.0
# 179   104.0         51.0
# 180    23.0         23.0
# 181     4.0          7.0
# 182    12.0         12.0
# 183    87.0         82.0
# 184    15.0          6.0
# 185   797.0        365.0
# 186   644.0        426.0
# 187     NaN          3.0
# 188     NaN          1.0
# 189     1.0          7.0
# 190   318.0        253.0
# 191    27.0         37.0
# 192   118.0         49.0
# 193     1.0          NaN
# 194     8.0          3.0
# 195     6.0          8.0
# 196  1295.0        804.0
# 197    59.0         19.0
# 198     5.0          4.0
# 199     1.0          NaN
# 200    24.0         20.0
# 201     6.0          8.0
#
# [202 rows x 8 columns]

# %%
all_inven = pd.read_csv("rentals/All/medianAskingRent_All.csv")
OneBd = pd.read_csv("rentals/OneBd/medianAskingRent_OneBd.csv")
Studio = pd.read_csv("rentals/Studio/medianAskingRent_Studio.csv")
ThreePlusBd = pd.read_csv("rentals/ThreePlusBd/medianAskingRent_ThreePlusBd.csv")
TwoBd = pd.read_csv("rentals/TwoBd/medianAskingRent_TwoBd.csv")

all_inven = all_inven[['areaName','Borough','areaType','2018-10']].rename(columns = {'2018-10':'All'})
OneBd = OneBd[['areaName','Borough','areaType','2018-10']].rename(columns = {'2018-10':'OneBd'})
Studio = Studio[['areaName','Borough','areaType','2018-10']].rename(columns = {'2018-10':'Studio'})
ThreePlusBd = ThreePlusBd[['areaName','Borough','areaType','2018-10']].rename(columns = {'2018-10':'ThreePlusBd'})
TwoBd = TwoBd[['areaName','Borough','areaType','2018-10']].rename(columns = {'2018-10':'TwoBd'})

price = pd.merge(all_inven,OneBd,on = ['areaName','Borough','areaType'])
price = pd.merge(price,Studio,on = ['areaName','Borough','areaType'])
price = pd.merge(price,TwoBd,on = ['areaName','Borough','areaType'])
price = pd.merge(price,ThreePlusBd,on = ['areaName','Borough','areaType'])
price
# Out:
#                 areaName        Borough      areaType     All   OneBd  Studio  \
# 0           All Downtown      Manhattan     submarket  3850.0  3651.0  2815.0
# 1            All Midtown      Manhattan     submarket  3595.0  3550.0  2595.0
# 2    All Upper East Side      Manhattan     submarket  3000.0  2888.0  2150.0
# 3    All Upper Manhattan      Manhattan     submarket  2350.0  1950.0  1750.0
# 4    All Upper West Side      Manhattan     submarket  3400.0  3200.0  2250.0
# 5             Alley Park         Queens  neighborhood     NaN     NaN     NaN
# 6                Astoria         Queens  neighborhood  2200.0  1900.0  1750.0
# 7             Auburndale         Queens  neighborhood  1945.0     NaN     NaN
# 8             Bath Beach       Brooklyn  neighborhood  1750.0  1537.0     NaN
# 9      Battery Park City      Manhattan  neighborhood  4900.0  3773.0  3250.0
# 10             Bay Ridge       Brooklyn  neighborhood  1999.0  1699.0  1595.0
# 11            Baychester          Bronx  neighborhood     NaN     NaN     NaN
# 12               Bayside         Queens  neighborhood  2400.0     NaN     NaN
# 13          Bedford Park          Bronx  neighborhood  1823.0     NaN     NaN
# 14    Bedford-Stuyvesant       Brooklyn  neighborhood  2500.0  2195.0  1948.0
# 15             Bellerose         Queens  neighborhood     NaN     NaN     NaN
# 16               Belmont          Bronx  neighborhood  2100.0     NaN     NaN
# 17           Bensonhurst       Brooklyn  neighborhood  1850.0  1550.0     NaN
# 18          Bergen Beach       Brooklyn  neighborhood  2088.0     NaN     NaN
# 19           Boerum Hill       Brooklyn  neighborhood  3250.0  2600.0     NaN
# 20          Borough Park       Brooklyn  neighborhood  1900.0  1550.0     NaN
# 21            Bowne Park         Queens  neighborhood     NaN     NaN     NaN
# 22             Briarwood         Queens  neighborhood  1750.0  1649.0     NaN
# 23        Brighton Beach       Brooklyn  neighborhood  2050.0  1750.0     NaN
# 24                 Bronx          Bronx       borough  1900.0  1600.0  1475.0
# 25             Bronxwood          Bronx  neighborhood  1625.0  1595.0     NaN
# 26              Brooklyn       Brooklyn       borough  2550.0  2250.0  2050.0
# 27      Brooklyn Heights       Brooklyn  neighborhood  3391.0  2998.0  2295.0
# 28            Brookville         Queens  neighborhood     NaN     NaN     NaN
# 29           Brownsville       Brooklyn  neighborhood  2025.0  1550.0     NaN
# ..                   ...            ...           ...     ...     ...     ...
# 172         South Queens         Queens     submarket  2000.0  1700.0  1550.0
# 173  South Richmond Hill         Queens  neighborhood     NaN     NaN     NaN
# 174  Springfield Gardens         Queens  neighborhood     NaN     NaN     NaN
# 175           St. Albans         Queens  neighborhood     NaN     NaN     NaN
# 176        Staten Island  Staten Island       borough  1900.0  1463.0  1690.0
# 177  Stuyvesant Town/PCV      Manhattan  neighborhood  4052.0  3653.0     NaN
# 178            Sunnyside         Queens  neighborhood  1935.0  1850.0  1653.0
# 179          Sunset Park       Brooklyn  neighborhood  1995.0  1700.0     NaN
# 180        The Rockaways         Queens     submarket  1850.0  1600.0  1395.0
# 181          Throgs Neck          Bronx  neighborhood  2150.0     NaN     NaN
# 182              Tremont          Bronx  neighborhood  1823.0     NaN     NaN
# 183              Tribeca      Manhattan  neighborhood  6860.0  4900.0  4275.0
# 184   University Heights          Bronx  neighborhood  1695.0  1535.0     NaN
# 185      Upper East Side      Manhattan  neighborhood  3000.0  2888.0  2150.0
# 186      Upper West Side      Manhattan  neighborhood  3400.0  3200.0  2250.0
# 187               Utopia         Queens  neighborhood     NaN     NaN     NaN
# 188             Van Nest          Bronx  neighborhood     NaN     NaN     NaN
# 189            Wakefield          Bronx  neighborhood  2100.0     NaN     NaN
# 190   Washington Heights      Manhattan  neighborhood  2250.0  1845.0  1695.0
# 191          West Harlem      Manhattan  neighborhood  2550.0  2000.0     NaN
# 192         West Village      Manhattan  neighborhood  3900.0  3825.0  2895.0
# 193  Westchester Village          Bronx  neighborhood     NaN     NaN     NaN
# 194           Whitestone         Queens  neighborhood  2250.0     NaN     NaN
# 195       Williamsbridge          Bronx  neighborhood  1825.0     NaN     NaN
# 196         Williamsburg       Brooklyn  neighborhood  3000.0  2775.0  2500.0
# 197      Windsor Terrace       Brooklyn  neighborhood  2643.0  2200.0     NaN
# 198            Woodhaven         Queens  neighborhood  1850.0     NaN     NaN
# 199             Woodlawn          Bronx  neighborhood     NaN     NaN     NaN
# 200             Woodside         Queens  neighborhood  1850.0  1785.0  1595.0
# 201            Woodstock          Bronx  neighborhood  1950.0     NaN     NaN
#
#       TwoBd  ThreePlusBd
# 0    4500.0       6060.0
# 1    4800.0       5959.0
# 2    3500.0       7895.0
# 3    2400.0       3025.0
# 4    4799.0       6998.0
# 5       NaN          NaN
# 6    2300.0       2800.0
# 7       NaN          NaN
# 8    1799.0       2500.0
# 9    6450.0      12000.0
# 10   2150.0       2595.0
# 11      NaN          NaN
# 12      NaN          NaN
# 13      NaN          NaN
# 14   2500.0       2995.0
# 15      NaN          NaN
# 16   1800.0       2200.0
# 17   1899.0       2450.0
# 18      NaN          NaN
# 19   3850.0       5800.0
# 20   1900.0       2350.0
# 21      NaN          NaN
# 22   1999.0          NaN
# 23   2497.0          NaN
# 24   1995.0       2350.0
# 25      NaN          NaN
# 26   2500.0       3000.0
# 27   4500.0       7400.0
# 28      NaN          NaN
# 29   1850.0       2295.0
# ..      ...          ...
# 172  2100.0       2500.0
# 173     NaN          NaN
# 174     NaN          NaN
# 175     NaN          NaN
# 176  2000.0       2300.0
# 177  3867.0       4606.0
# 178  2325.0       2875.0
# 179  2000.0       2400.0
# 180  2100.0       2399.0
# 181     NaN          NaN
# 182  1800.0       2152.0
# 183  7950.0      15170.0
# 184  1750.0          NaN
# 185  3500.0       7895.0
# 186  4799.0       6998.0
# 187     NaN          NaN
# 188     NaN          NaN
# 189     NaN          NaN
# 190  2295.0       2950.0
# 191  2300.0       2999.0
# 192  4744.0       7995.0
# 193     NaN          NaN
# 194     NaN          NaN
# 195     NaN          NaN
# 196  3025.0       3599.0
# 197  2900.0       3195.0
# 198     NaN          NaN
# 199     NaN          NaN
# 200  2200.0       2625.0
# 201     NaN          NaN
#
# [202 rows x 8 columns]

# %%
OneBd = pd.read_csv("rentals/OneBd/medianAskingRent_OneBd.csv")

OneBd
# Out:
#                 areaName        Borough      areaType  2010-01  2010-02  \
# 0           All Downtown      Manhattan     submarket   2999.0   2975.0
# 1            All Midtown      Manhattan     submarket   2800.0   2800.0
# 2    All Upper East Side      Manhattan     submarket   2350.0   2300.0
# 3    All Upper Manhattan      Manhattan     submarket   1500.0   1516.0
# 4    All Upper West Side      Manhattan     submarket   2600.0   2550.0
# 5             Alley Park         Queens  neighborhood      NaN      NaN
# 6                Astoria         Queens  neighborhood   1395.0   1450.0
# 7             Auburndale         Queens  neighborhood      NaN      NaN
# 8             Bath Beach       Brooklyn  neighborhood      NaN      NaN
# 9      Battery Park City      Manhattan  neighborhood   2875.0   2800.0
# 10             Bay Ridge       Brooklyn  neighborhood   1350.0   1350.0
# 11            Baychester          Bronx  neighborhood      NaN      NaN
# 12               Bayside         Queens  neighborhood      NaN      NaN
# 13          Bedford Park          Bronx  neighborhood      NaN      NaN
# 14    Bedford-Stuyvesant       Brooklyn  neighborhood   1600.0   1500.0
# 15             Bellerose         Queens  neighborhood      NaN      NaN
# 16               Belmont          Bronx  neighborhood      NaN      NaN
# 17           Bensonhurst       Brooklyn  neighborhood      NaN      NaN
# 18          Bergen Beach       Brooklyn  neighborhood      NaN      NaN
# 19           Boerum Hill       Brooklyn  neighborhood   2000.0   1950.0
# 20          Borough Park       Brooklyn  neighborhood      NaN      NaN
# 21            Bowne Park         Queens  neighborhood      NaN      NaN
# 22             Briarwood         Queens  neighborhood      NaN      NaN
# 23        Brighton Beach       Brooklyn  neighborhood      NaN      NaN
# 24                 Bronx          Bronx       borough   1350.0   1400.0
# 25             Bronxwood          Bronx  neighborhood      NaN      NaN
# 26              Brooklyn       Brooklyn       borough   1950.0   1938.0
# 27      Brooklyn Heights       Brooklyn  neighborhood   2000.0   1950.0
# 28            Brookville         Queens  neighborhood      NaN      NaN
# 29           Brownsville       Brooklyn  neighborhood      NaN      NaN
# ..                   ...            ...           ...      ...      ...
# 172         South Queens         Queens     submarket      NaN      NaN
# 173  South Richmond Hill         Queens  neighborhood      NaN      NaN
# 174  Springfield Gardens         Queens  neighborhood      NaN      NaN
# 175           St. Albans         Queens  neighborhood      NaN      NaN
# 176        Staten Island  Staten Island       borough      NaN      NaN
# 177  Stuyvesant Town/PCV      Manhattan  neighborhood      NaN      NaN
# 178            Sunnyside         Queens  neighborhood   1350.0   1350.0
# 179          Sunset Park       Brooklyn  neighborhood   1200.0   1200.0
# 180        The Rockaways         Queens     submarket      NaN      NaN
# 181          Throgs Neck          Bronx  neighborhood      NaN      NaN
# 182              Tremont          Bronx  neighborhood      NaN      NaN
# 183              Tribeca      Manhattan  neighborhood   3960.0   4000.0
# 184   University Heights          Bronx  neighborhood      NaN      NaN
# 185      Upper East Side      Manhattan  neighborhood   2350.0   2300.0
# 186      Upper West Side      Manhattan  neighborhood   2600.0   2550.0
# 187               Utopia         Queens  neighborhood      NaN      NaN
# 188             Van Nest          Bronx  neighborhood      NaN      NaN
# 189            Wakefield          Bronx  neighborhood      NaN      NaN
# 190   Washington Heights      Manhattan  neighborhood   1400.0   1395.0
# 191          West Harlem      Manhattan  neighborhood      NaN      NaN
# 192         West Village      Manhattan  neighborhood   3298.0   3100.0
# 193  Westchester Village          Bronx  neighborhood      NaN      NaN
# 194           Whitestone         Queens  neighborhood      NaN      NaN
# 195       Williamsbridge          Bronx  neighborhood      NaN      NaN
# 196         Williamsburg       Brooklyn  neighborhood   2383.0   2350.0
# 197      Windsor Terrace       Brooklyn  neighborhood      NaN      NaN
# 198            Woodhaven         Queens  neighborhood      NaN      NaN
# 199             Woodlawn          Bronx  neighborhood      NaN      NaN
# 200             Woodside         Queens  neighborhood      NaN      NaN
# 201            Woodstock          Bronx  neighborhood      NaN      NaN
#
#      2010-03  2010-04  2010-05  2010-06  2010-07   ...     2018-01  2018-02  \
# 0     2900.0   2982.0   2995.0   3000.0   3000.0   ...      3500.0   3583.0
# 1     2850.0   2895.0   2900.0   2990.0   3000.0   ...      3351.0   3387.0
# 2     2350.0   2470.0   2500.0   2500.0   2500.0   ...      2800.0   2750.0
# 3     1545.0   1516.0   1550.0   1575.0   1550.0   ...      1900.0   1950.0
# 4     2495.0   2500.0   2500.0   2600.0   2600.0   ...      3100.0   3078.0
# 5        NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 6     1450.0   1395.0   1400.0   1550.0   1475.0   ...      1850.0   1850.0
# 7        NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 8        NaN      NaN      NaN      NaN      NaN   ...      1500.0      NaN
# 9     2900.0   2873.0   2800.0   2900.0   2950.0   ...      3499.0   3475.0
# 10    1350.0   1325.0   1300.0   1300.0   1300.0   ...      1650.0   1675.0
# 11       NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 12       NaN      NaN      NaN      NaN      NaN   ...         NaN   1725.0
# 13       NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 14    1350.0   1375.0   1400.0   1350.0   1300.0   ...      2000.0   2000.0
# 15       NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 16       NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 17       NaN      NaN      NaN      NaN      NaN   ...      1573.0   1595.0
# 18       NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 19    1975.0   2050.0   2050.0   2360.0   2355.0   ...      2375.0   2500.0
# 20       NaN      NaN      NaN      NaN      NaN   ...      1590.0   1500.0
# 21       NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 22       NaN      NaN      NaN      NaN      NaN   ...      1625.0   1695.0
# 23       NaN      NaN      NaN      NaN      NaN   ...      1719.0   1895.0
# 24    1400.0   1375.0   1400.0   1300.0   1200.0   ...      1550.0   1578.0
# 25       NaN      NaN      NaN      NaN      NaN   ...         NaN   1600.0
# 26    1897.0   1941.0   2000.0   2000.0   2050.0   ...      2200.0   2200.0
# 27    1850.0   1863.0   2200.0   2200.0   2398.0   ...      2870.0   2796.0
# 28       NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 29       NaN      NaN      NaN      NaN      NaN   ...      1550.0   1599.0
# ..       ...      ...      ...      ...      ...   ...         ...      ...
# 172      NaN      NaN      NaN      NaN      NaN   ...      1600.0   1600.0
# 173      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 174      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 175      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 176      NaN      NaN      NaN      NaN      NaN   ...      1600.0   1600.0
# 177      NaN      NaN      NaN      NaN      NaN   ...      3585.0   3623.0
# 178   1350.0   1399.0   1400.0   1375.0   1400.0   ...      1875.0   1900.0
# 179   1175.0   1188.0   1200.0      NaN      NaN   ...      1650.0   1650.0
# 180      NaN      NaN      NaN      NaN      NaN   ...         NaN   1585.0
# 181      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 182      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 183   3900.0   3900.0   3825.0   3695.0   3695.0   ...      4495.0   4500.0
# 184      NaN      NaN      NaN      NaN      NaN   ...      1499.0   1500.0
# 185   2350.0   2470.0   2500.0   2500.0   2500.0   ...      2800.0   2750.0
# 186   2495.0   2500.0   2500.0   2600.0   2600.0   ...      3100.0   3078.0
# 187      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 188      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 189      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 190   1395.0   1397.0   1355.0   1433.0   1495.0   ...      1795.0   1798.0
# 191      NaN      NaN      NaN      NaN      NaN   ...      2725.0   2725.0
# 192   3000.0   3048.0   3000.0   3095.0   3288.0   ...      3500.0   3750.0
# 193      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 194      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 195      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 196   2304.0   2450.0   2450.0   2585.0   2558.0   ...      2800.0   2800.0
# 197      NaN      NaN      NaN      NaN   1800.0   ...      2200.0   2250.0
# 198      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 199      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
# 200      NaN      NaN      NaN      NaN      NaN   ...      1690.0   1700.0
# 201      NaN      NaN      NaN      NaN      NaN   ...         NaN      NaN
#
#      2018-03  2018-04  2018-05  2018-06  2018-07  2018-08  2018-09  2018-10
# 0     3575.0   3546.0   3500.0   3500.0   3500.0   3560.0   3600.0   3651.0
# 1     3375.0   3395.0   3495.0   3500.0   3500.0   3500.0   3550.0   3550.0
# 2     2775.0   2697.0   2695.0   2800.0   2795.0   2795.0   2795.0   2888.0
# 3     1950.0   1995.0   2000.0   2000.0   1995.0   1957.0   1950.0   1950.0
# 4     3095.0   3100.0   3100.0   3100.0   3050.0   3050.0   3150.0   3200.0
# 5        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 6     1850.0   1873.0   1900.0   1850.0   1900.0   1900.0   1938.0   1900.0
# 7        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 8        NaN      NaN   1550.0   1625.0   1500.0   1500.0   1499.0   1537.0
# 9     3595.0   3575.0   3698.0   3650.0   3950.0   3950.0   3850.0   3773.0
# 10    1650.0   1675.0   1675.0   1700.0   1699.0   1700.0   1700.0   1699.0
# 11       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 12    1650.0      NaN   1625.0      NaN      NaN      NaN      NaN      NaN
# 13       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14    2100.0   2100.0   2100.0   2149.0   2140.0   2197.0   2200.0   2195.0
# 15       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 16       NaN      NaN      NaN      NaN      NaN   1575.0      NaN      NaN
# 17    1505.0   1550.0   1650.0   1588.0   1550.0   1525.0   1575.0   1550.0
# 18       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 19    2500.0   2600.0   2768.0   2700.0   2655.0   2800.0   2700.0   2600.0
# 20    1598.0   1590.0   1550.0   1600.0   1620.0   1620.0   1550.0   1550.0
# 21       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 22    1699.0   1695.0   1685.0   1700.0   1699.0   1600.0   1650.0   1649.0
# 23    1825.0   1744.0   1875.0   1900.0   1900.0   1900.0   1750.0   1750.0
# 24    1550.0   1580.0   1578.0   1550.0   1575.0   1600.0   1625.0   1600.0
# 25    1450.0   1450.0      NaN   1550.0   1550.0   1575.0   1550.0   1595.0
# 26    2200.0   2250.0   2250.0   2275.0   2300.0   2300.0   2300.0   2250.0
# 27    2800.0   2796.0   2900.0   2900.0   2800.0   3000.0   2784.0   2998.0
# 28       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 29       NaN   1475.0   1475.0   1488.0      NaN      NaN      NaN   1550.0
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 172   1700.0   1650.0   1650.0   1750.0   1797.0   1745.0   1689.0   1700.0
# 173      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 174      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 175      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 176   1600.0   1513.0   1500.0   1695.0   1995.0   1550.0   1879.0   1463.0
# 177   3580.0   3655.0   3609.0      NaN   3549.0   3587.0   3635.0   3653.0
# 178   1900.0   1945.0   1900.0   1885.0   1850.0   1800.0   1850.0   1850.0
# 179   1750.0   1747.0   1750.0   1700.0   1713.0   1700.0   1719.0   1700.0
# 180      NaN      NaN   1600.0   1599.0   1650.0   1600.0   1650.0   1600.0
# 181      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 182      NaN      NaN      NaN      NaN      NaN   1538.0      NaN      NaN
# 183   4500.0   4673.0   4695.0   4625.0   4500.0   4598.0   4695.0   4900.0
# 184   1450.0   1450.0   1463.0   1450.0      NaN      NaN      NaN   1535.0
# 185   2775.0   2697.0   2695.0   2800.0   2795.0   2795.0   2795.0   2888.0
# 186   3095.0   3100.0   3100.0   3100.0   3050.0   3050.0   3150.0   3200.0
# 187      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 188      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 189      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 190   1795.0   1795.0   1802.0   1850.0   1825.0   1818.0   1800.0   1845.0
# 191   2300.0   2363.0   2348.0   2200.0   1950.0   1850.0   2000.0   2000.0
# 192   3750.0   3750.0   3780.0   3798.0   3800.0   3923.0   3895.0   3825.0
# 193      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 194      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 196   2795.0   2800.0   2750.0   2756.0   2750.0   2750.0   2700.0   2775.0
# 197   2198.0   2200.0   2225.0   2199.0   2200.0   2100.0   2138.0   2200.0
# 198      NaN   1625.0   1549.0      NaN      NaN      NaN      NaN      NaN
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 200   1750.0   1790.0   1790.0   1790.0   1750.0   1763.0   1750.0   1785.0
# 201      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [202 rows x 109 columns]

# %%
inventory = inventory[inventory['areaType']=='borough']
inventory
# Out:
#           areaName        Borough areaType    All   OneBd  Studio   TwoBd  \
# 24           Bronx          Bronx  borough   1154   404.0    91.0   367.0
# 26        Brooklyn       Brooklyn  borough  17556  5022.0  1277.0  6381.0
# 110      Manhattan      Manhattan  borough  19604  7369.0  3788.0  5444.0
# 153         Queens         Queens  borough   5581  2190.0   603.0  1822.0
# 176  Staten Island  Staten Island  borough     97    36.0    11.0    25.0
#
#      ThreePlusBd
# 24         292.0
# 26        4876.0
# 110       3003.0
# 153        966.0
# 176         25.0

# %%
price = price[price['areaType']=='borough']
price
# Out:
#           areaName        Borough areaType     All   OneBd  Studio   TwoBd  \
# 24           Bronx          Bronx  borough  1900.0  1600.0  1475.0  1995.0
# 26        Brooklyn       Brooklyn  borough  2550.0  2250.0  2050.0  2500.0
# 110      Manhattan      Manhattan  borough  3300.0  3200.0  2450.0  3825.0
# 153         Queens         Queens  borough  2200.0  1900.0  1700.0  2300.0
# 176  Staten Island  Staten Island  borough  1900.0  1463.0  1690.0  2000.0
#
#      ThreePlusBd
# 24        2350.0
# 26        3000.0
# 110       4999.0
# 153       2795.0
# 176       2300.0

# %% [markdown]
# # Airbnb listings 9/12/2019

# %%
listings = pd.read_csv("listings.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (61,62,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for i in listings.columns:
    print(i,'|||',listings[i][0])
# Out:
# id ||| 3647
# listing_url ||| https://www.airbnb.com/rooms/3647
# scrape_id ||| 20190912153101
# last_scraped ||| 2019-09-13
# name ||| THE VILLAGE OF HARLEM....NEW YORK !
# summary ||| nan
# space ||| WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY This Spacious 1 bedroom  is with Plenty of Windows with a View....... Sleeps.....Four Adults.....two in the Livingrm. with (2) Sofa-beds.  (Website hidden by Airbnb) two in the Bedrm.on a very Comfortable Queen Size Bed... A Complete Bathrm.....With Shower and Bathtub....... Fully Equipped with Linens & Towels........ Spacious Living Room......Flat ScreenTelevision.....DVD Player with Movies available for your viewing during your stay............................................................................. Dining Area.....for Morning Coffee or Tea..................................................... The Kitchen Area is Modern with Granite Counter Top... includes the use of a Coffee Maker...Microwave to Heat up a Carry Out/In Meal.... Not suited for a Gourmet Cook...or Top Chef......Sorry!!!! . This Flat is located in HISTORIC HARLEM.... near the Appollo Theater and The Museum Mile...on Fifth Avenue. Sylvia's World Famous Resturant...loca
# description ||| WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY This Spacious 1 bedroom  is with Plenty of Windows with a View....... Sleeps.....Four Adults.....two in the Livingrm. with (2) Sofa-beds.  (Website hidden by Airbnb) two in the Bedrm.on a very Comfortable Queen Size Bed... A Complete Bathrm.....With Shower and Bathtub....... Fully Equipped with Linens & Towels........ Spacious Living Room......Flat ScreenTelevision.....DVD Player with Movies available for your viewing during your stay............................................................................. Dining Area.....for Morning Coffee or Tea..................................................... The Kitchen Area is Modern with Granite Counter Top... includes the use of a Coffee Maker...Microwave to Heat up a Carry Out/In Meal.... Not suited for a Gourmet Cook...or Top Chef......Sorry!!!! . This Flat is located in HISTORIC HARLEM.... near the Appollo Theater and The Museum Mile...on Fifth Avenue. Sylvia's World Famous Resturant...loca
# experiences_offered ||| none
# neighborhood_overview ||| nan
# notes ||| nan
# transit ||| nan
# access ||| nan
# interaction ||| nan
# house_rules ||| Upon arrival please have a legibile copy of your Passport  and / or State Photo. ID. as well as your confirmation letter. Please NO SMOKING ...LOUD TALKING or PARTIES of any kind. Security Deposit and Cleaning Fees in CASH at time of arrival. Security deposit will be refunded within 72hrs pending no damages. .Cleaning fees are non-refundable. At Check Out... Please dispose of all trash/garbage in the bins located outside behind the entrance stairs. Please place all dirty linens and towels in the dirty laundry bin. Please don't leave any dishes in the sink and dispose of all Plastic Dishes/Plastic Culinary. If you need a late check-out please contact the Emergency Contact Telephone Numbers that are listed in the Flat. PLEASE LEAVE ALL KEYS IN THE FLAT and BE CERTAIN THE DOORS ARE LOCKED. WE HOPE YOU ENJOYED YOUR STAY and will write positve comments and will visit again.
# thumbnail_url ||| nan
# medium_url ||| nan
# picture_url ||| https://a0.muscache.com/im/pictures/838341/9b3c66f3_original.jpg?aki_policy=large
# xl_picture_url ||| nan
# host_id ||| 4632
# host_url ||| https://www.airbnb.com/users/show/4632
# host_name ||| Elisabeth
# host_since ||| 2008-11-25
# host_location ||| New York, New York, United States
# host_about ||| Make Up Artist National/ (Website hidden by Airbnb) Production.
# I m curently working with a Production Company in WDC and Coordinated a "Day Of Service " for the Presidential Innaugration 2013.
# I can't live without Starbucks and Oprah's Chai Tea Latte...and my circle of  of  great friends world wide. "BLESS ME INTO USEFULLNESS" is my daily prayer.
# I
# host_response_time ||| a few days or more
# host_response_rate ||| 0%
# host_acceptance_rate ||| nan
# host_is_superhost ||| f
# host_thumbnail_url ||| https://a0.muscache.com/im/users/4632/profile_pic/1328402497/original.jpg?aki_policy=profile_small
# host_picture_url ||| https://a0.muscache.com/im/users/4632/profile_pic/1328402497/original.jpg?aki_policy=profile_x_medium
# host_neighbourhood ||| Harlem
# host_listings_count ||| 1.0
# host_total_listings_count ||| 1.0
# host_verifications ||| ['email', 'phone', 'google', 'reviews', 'jumio', 'government_id']
# host_has_profile_pic ||| t
# host_identity_verified ||| t
# street ||| New York, NY, United States
# neighbourhood ||| Harlem
# neighbourhood_cleansed ||| Harlem
# neighbourhood_group_cleansed ||| Manhattan
# city ||| New York
# state ||| NY
# zipcode ||| 10027
# market ||| New York
# smart_location ||| New York, NY
# country_code ||| US
# country ||| United States
# latitude ||| 40.80902
# longitude ||| -73.9419
# is_location_exact ||| t
# property_type ||| Apartment
# room_type ||| Private room
# accommodates ||| 2
# bathrooms ||| 1.0
# bedrooms ||| 1.0
# beds ||| 1.0
# bed_type ||| Pull-out Sofa
# amenities ||| {"Cable TV",Internet,Wifi,"Air conditioning",Kitchen,"Buzzer/wireless intercom",Heating,"Smoke detector","Carbon monoxide detector","translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}
# square_feet ||| nan
# price ||| $150.00
# weekly_price ||| nan
# monthly_price ||| nan
# security_deposit ||| $200.00
# cleaning_fee ||| $75.00
# guests_included ||| 2
# extra_people ||| $20.00
# minimum_nights ||| 3
# maximum_nights ||| 7
# minimum_minimum_nights ||| 3
# maximum_minimum_nights ||| 3
# minimum_maximum_nights ||| 7
# maximum_maximum_nights ||| 7
# minimum_nights_avg_ntm ||| 3.0
# maximum_nights_avg_ntm ||| 7.0
# calendar_updated ||| 37 months ago
# has_availability ||| t
# availability_30 ||| 30
# availability_60 ||| 60
# availability_90 ||| 90
# availability_365 ||| 365
# calendar_last_scraped ||| 2019-09-13
# number_of_reviews ||| 0
# number_of_reviews_ltm ||| 0
# first_review ||| nan
# last_review ||| nan
# review_scores_rating ||| nan
# review_scores_accuracy ||| nan
# review_scores_cleanliness ||| nan
# review_scores_checkin ||| nan
# review_scores_communication ||| nan
# review_scores_location ||| nan
# review_scores_value ||| nan
# requires_license ||| f
# license ||| nan
# jurisdiction_names ||| nan
# instant_bookable ||| f
# is_business_travel_ready ||| f
# cancellation_policy ||| strict_14_with_grace_period
# require_guest_profile_picture ||| t
# require_guest_phone_verification ||| t
# calculated_host_listings_count ||| 1
# calculated_host_listings_count_entire_homes ||| 0
# calculated_host_listings_count_private_rooms ||| 1
# calculated_host_listings_count_shared_rooms ||| 0
# reviews_per_month ||| nan

# %%
listings = listings[['neighbourhood_cleansed','neighbourhood_group_cleansed','city', 'state', 'zipcode', 'market','latitude', 'longitude','property_type', 'room_type', 'accommodates',
       'bathrooms', 'bedrooms', 'beds', 'bed_type','price', 'weekly_price', 'monthly_price','has_availability', 'availability_30', 'availability_60',
       'availability_90', 'availability_365']]

# %%
listings['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'], dtype=object)

# %%
listings = listings[listings['room_type'] == 'Entire home/apt']

# %%
listings['bedrooms'].value_counts()
# Out:
# 1.0     12406
# 2.0      5867
# 0.0      4018
# 3.0      1917
# 4.0       466
# 5.0       124
# 6.0        37
# 7.0        17
# 8.0         8
# 9.0         4
# 10.0        3
# 21.0        1
# 14.0        1
# Name: bedrooms, dtype: int64

# %%
listings.loc[listings['bedrooms'] > 3,'bedrooms'] = 3

# %%
listings['bedrooms'].value_counts()
# Out:
# 1.0    12406
# 2.0     5867
# 0.0     4018
# 3.0     2578
# Name: bedrooms, dtype: int64

# %%
listings['price'] = listings['price'].apply(lambda x: float(x.strip('$').replace(',','')))

# %%
airbnb_all = listings.groupby(['neighbourhood_group_cleansed'])[['price']].agg(['median','count']).reset_index().rename(columns = {'neighbourhood_group_cleansed':'Borough'})

# %%
listings = listings.groupby(['neighbourhood_group_cleansed','bedrooms'])[['price']].agg(['median','count']).reset_index().rename(columns = {'neighbourhood_group_cleansed':'Borough'})

# %%
airbnb_all.columns = [' '.join(col).strip() for col in airbnb_all.columns.values]
airbnb_all = airbnb_all.rename(columns = {'price median':'airbnb_price','price count':'airbnb_inventory'})

# %%
listings.columns = [' '.join(col).strip() for col in listings.columns.values]
listings = listings.rename(columns = {'price median':'airbnb_price','price count':'airbnb_inventory'})
listings
# Out:
#           Borough  bedrooms  airbnb_price  airbnb_inventory
# 0           Bronx       0.0          95.0                49
# 1           Bronx       1.0          90.0               195
# 2           Bronx       2.0         114.5                88
# 3           Bronx       3.0         190.0                59
# 4        Brooklyn       0.0         112.5               972
# 5        Brooklyn       1.0         125.0              4521
# 6        Brooklyn       2.0         160.0              2612
# 7        Brooklyn       3.0         250.0              1253
# 8       Manhattan       0.0         150.0              2727
# 9       Manhattan       1.0         180.0              6575
# 10      Manhattan       2.0         250.0              2628
# 11      Manhattan       3.0         400.0               879
# 12         Queens       0.0          96.0               249
# 13         Queens       1.0         100.0              1049
# 14         Queens       2.0         140.0               494
# 15         Queens       3.0         200.0               340
# 16  Staten Island       0.0          70.0                21
# 17  Staten Island       1.0          89.5                66
# 18  Staten Island       2.0         100.0                45
# 19  Staten Island       3.0         180.0                47

# %%
listings.loc[:,'bedrooms'] = listings['bedrooms'].map({0:'Studio',1:'OneBd',2:'TwoBd',3:'ThreePlusBd'})

# %%
airbnb_all['bedrooms'] = 'All'
# Out:
#          Borough  airbnb_price  airbnb_inventory bedrooms
# 0          Bronx         100.0               392      All
# 1       Brooklyn         145.0              9364      All
# 2      Manhattan         194.0             12828      All
# 3         Queens         120.0              2135      All
# 4  Staten Island         100.0               179      All

# %%
airbnb = pd.concat([airbnb_all,listings])
airbnb
# Out:
#           Borough  airbnb_inventory  airbnb_price     bedrooms
# 0           Bronx               392         100.0          All
# 1        Brooklyn              9364         145.0          All
# 2       Manhattan             12828         194.0          All
# 3          Queens              2135         120.0          All
# 4   Staten Island               179         100.0          All
# 0           Bronx                49          95.0       Studio
# 1           Bronx               195          90.0        OneBd
# 2           Bronx                88         114.5        TwoBd
# 3           Bronx                59         190.0  ThreePlusBd
# 4        Brooklyn               972         112.5       Studio
# 5        Brooklyn              4521         125.0        OneBd
# 6        Brooklyn              2612         160.0        TwoBd
# 7        Brooklyn              1253         250.0  ThreePlusBd
# 8       Manhattan              2727         150.0       Studio
# 9       Manhattan              6575         180.0        OneBd
# 10      Manhattan              2628         250.0        TwoBd
# 11      Manhattan               879         400.0  ThreePlusBd
# 12         Queens               249          96.0       Studio
# 13         Queens              1049         100.0        OneBd
# 14         Queens               494         140.0        TwoBd
# 15         Queens               340         200.0  ThreePlusBd
# 16  Staten Island                21          70.0       Studio
# 17  Staten Island                66          89.5        OneBd
# 18  Staten Island                45         100.0        TwoBd
# 19  Staten Island                47         180.0  ThreePlusBd

# %% [markdown]
# merge airbnb median price and inventory data with rental data

# %%
price = pd.melt(price, id_vars=['Borough'], value_vars=['All', 'Studio','OneBd','TwoBd','ThreePlusBd']).rename(columns = {'variable':'type','value':'price'})
inventory = pd.melt(inventory, id_vars=['Borough'], value_vars=['All', 'Studio','OneBd','TwoBd','ThreePlusBd']).rename(columns = {'variable':'type','value':'inventory'})
# Out:
#          Borough type   price  inventory
# 0          Bronx  All  1900.0     1154.0
# 1       Brooklyn  All  2550.0    17556.0
# 2      Manhattan  All  3300.0    19604.0
# 3         Queens  All  2200.0     5581.0
# 4  Staten Island  All  1900.0       97.0

# %%
rental = price.merge(inventory,on = ['Borough','type'])

# %%
host = rental.merge(airbnb, left_on = ['Borough','type'], right_on=['Borough','bedrooms'])

# %%
host = host.drop(['bedrooms'], axis = 1).rename(columns = {'price':'rental_price','inventory':'rental_inventory'})

# %%
host.to_csv('../data/host.csv')

# %% [markdown]
# ## calendar

# %%
calendar = pd.read_csv("calendar.csv")

# %%
calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0        9668  2019-09-13         f   $51.00         $51.00             3.0
# 1       26969  2019-09-13         f  $350.00        $350.00             3.0
# 2       26969  2019-09-14         f  $350.00        $350.00             3.0
# 3       26969  2019-09-15         f  $350.00        $350.00             3.0
# 4       26969  2019-09-16         f  $350.00        $350.00             3.0
#
#    maximum_nights
# 0           365.0
# 1            33.0
# 2            33.0
# 3            33.0
# 4            33.0

# %%
(calendar['available'] == 't').sum()
# Out:
# 5555557

# %%
(calendar['available'] != 't').sum()
# Out:
# 12102211

# %%
len(calendar)
# Out:
# 17657768

# %%
len(calendar['listing_id'].unique())
# Out:
# 48377

# %%
17657768/48377
# Out:
# 365.00336936974185

# %%
calendar = calendar[~calendar['price'].isnull()]
calendar = calendar[~calendar['adjusted_price'].isnull()]

# %%
calendar['price'] = calendar['price'].apply(lambda x: float(x.strip('$').replace(',','')))
calendar['adjusted_price'] = calendar['adjusted_price'].apply(lambda x: float(x.strip('$').replace(',','')))

# %%
calendar['available'] = calendar['available']=='t'

# %%
grouped = calendar.groupby('listing_id').agg({'price':['mean','std'],'adjusted_price':['mean','std'],'available':['mean','std']})
# grouped = calendar.groupby('listing_id').agg({'price':['mean','std'],'available':['mean','std']})

# %%
grouped['price_std/mean'] = grouped['price','std']/grouped['price','mean']

# %%
grouped.head()
# Out:
#                  price            adjusted_price            available  \
#                   mean        std           mean        std      mean
# listing_id
# 3647        150.000000   0.000000     150.000000   0.000000  1.000000
# 3831         84.594521   6.650619      84.594521   6.650619  0.526027
# 5022         81.438356   2.266492      81.438356   2.266492  0.000000
# 5099        203.780822  14.632163     203.780822  14.632163  0.035616
# 5121         60.000000   0.000000      60.000000   0.000000  0.868493
#
#                      price_std/mean
#                  std
# listing_id
# 3647        0.000000       0.000000
# 3831        0.500008       0.078618
# 5022        0.000000       0.027831
# 5099        0.185586       0.071803
# 5121        0.338418       0.000000

# %%
grouped['available','mean'].median()
# Out:
# 0.13424657534246576

# %%
grouped['price_std/mean'].median()
# Out:
# 0.055414738129490285

# %%
grouped['price_std/mean'].quantile(0.8)
# Out:
# 0.11110210934227743

# %%
grouped['price'].median()
# Out:
# mean    110.000000
# std       5.184425
# dtype: float64

# %%
# mask = (grouped['price_std/mean']<0.0556)&(grouped['price_std/mean']>0.0552)
mask = (grouped['price_std/mean']<0.12)&(grouped['price_std/mean']>0.10)

mask = mask&(grouped['price','mean']>100)&(grouped['price','mean']<120)
mask = mask&(grouped['available','mean']>0.11)&(grouped['available','mean']<0.16)

# %%
grouped[mask]
# Out:
#                  price            adjusted_price            available  \
#                   mean        std           mean        std      mean
# listing_id
# 2033846     101.813699  10.615836     101.813699  10.615836  0.123288
# 5803875     102.912329  11.166472     102.912329  11.166472  0.117808
# 8012976     101.958904  11.637660     101.958904  11.637660  0.147945
# 9861747     111.873973  11.922852     111.873973  11.922852  0.112329
# 13606307    110.906849  12.368521     110.906849  12.368521  0.153425
# 19827778    113.717808  13.064079     113.717808  13.064079  0.145205
# 20285167    100.021918  11.940308     100.021918  11.940308  0.139726
# 24324891    117.408219  12.022206     117.408219  12.022206  0.120548
# 24829645    119.643836  14.282636     119.643836  14.282636  0.123288
# 28341857    108.416438  11.580666     108.416438  11.580666  0.150685
# 32045160    102.205479  11.183729     102.205479  11.183729  0.153425
# 32664982    101.076712  11.087793     101.076712  11.087793  0.117808
# 33915820    110.402740  11.776046     110.402740  11.776046  0.145205
# 34364713    102.975342  11.523361     102.975342  11.523361  0.131507
# 36385709    101.863014  11.306561     101.863014  11.306561  0.134247
# 36881756    103.898630  10.488252     103.898630  10.488252  0.128767
# 36973823    102.183562  10.783675     102.183562  10.783675  0.131507
#
#                      price_std/mean
#                  std
# listing_id
# 2033846     0.329218       0.104267
# 5803875     0.322823       0.108505
# 8012976     0.355533       0.114141
# 9861747     0.316204       0.106574
# 13606307    0.360891       0.111522
# 19827778    0.352791       0.114882
# 20285167    0.347178       0.119377
# 24324891    0.326048       0.102397
# 24829645    0.329218       0.119376
# 28341857    0.358233       0.106817
# 32045160    0.360891       0.109424
# 32664982    0.322823       0.109697
# 33915820    0.352791       0.106664
# 34364713    0.338418       0.111904
# 36385709    0.341385       0.110998
# 36881756    0.335402       0.100947
# 36973823    0.338418       0.105532

# %%
id_list = grouped[mask].index

# %%
id_list
# Out:
# Int64Index([ 2033846,  5803875,  8012976,  9861747, 13606307, 19827778,
#             20285167, 24324891, 24829645, 28341857, 32045160, 32664982,
#             33915820, 34364713, 36385709, 36881756, 36973823],
#            dtype='int64', name='listing_id')

# %%
data = []
for list_id in id_list:
    selected = calendar[calendar['listing_id']==list_id]
    d = {}
    d['listing_id'] = str(list_id)
    d['date'] = list(selected['date'])
    d['price'] = list(selected['price'])
    d['available'] = list(selected['available'].apply(lambda x: str(x)))
    data.append(d)

# %%
import json
# import numpy as np
# class CustomJSONEncoder(json.JSONEncoder):
#     def default(self, obj):
#         if isinstance(obj, np.bool_):
#             return super(DateTimeJSONEncoder, self).encode(bool(obj))

#         return super(DateTimeJSONEncoder, self).default(obj)
   
with open('variability.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
selected = selected[['listing_id','date','available','price']]

# %%
list(selected['date'])
# Out:
# ['2019-09-13',
#  '2019-09-14',
#  '2019-09-15',
#  '2019-09-16',
#  '2019-09-17',
#  '2019-09-18',
#  '2019-09-19',
#  '2019-09-20',
#  '2019-09-21',
#  '2019-09-22',
#  '2019-09-23',
#  '2019-09-24',
#  '2019-09-25',
#  '2019-09-26',
#  '2019-09-27',
#  '2019-09-28',
#  '2019-09-29',
#  '2019-09-30',
#  '2019-10-01',
#  '2019-10-02',
#  '2019-10-03',
#  '2019-10-04',
#  '2019-10-05',
#  '2019-10-06',
#  '2019-10-07',
#  '2019-10-08',
#  '2019-10-09',
#  '2019-10-10',
#  '2019-10-11',
#  '2019-10-12',
#  '2019-10-13',
#  '2019-10-14',
#  '2019-10-15',
#  '2019-10-16',
#  '2019-10-17',
#  '2019-10-18',
#  '2019-10-19',
#  '2019-10-20',
#  '2019-10-21',
#  '2019-10-22',
#  '2019-10-23',
#  '2019-10-24',
#  '2019-10-25',
#  '2019-10-26',
#  '2019-10-27',
#  '2019-10-28',
#  '2019-10-29',
#  '2019-10-30',
#  '2019-10-31',
#  '2019-11-01',
#  '2019-11-02',
#  '2019-11-03',
#  '2019-11-04',
#  '2019-11-05',
#  '2019-11-06',
#  '2019-11-07',
#  '2019-11-08',
#  '2019-11-09',
#  '2019-11-10',
#  '2019-11-11',
#  '2019-11-12',
#  '2019-11-13',
#  '2019-11-14',
#  '2019-11-15',
#  '2019-11-16',
#  '2019-11-17',
#  '2019-11-18',
#  '2019-11-19',
#  '2019-11-20',
#  '2019-11-21',
#  '2019-11-22',
#  '2019-11-23',
#  '2019-11-24',
#  '2019-11-25',
#  '2019-11-26',
#  '2019-11-27',
#  '2019-11-28',
#  '2019-11-29',
#  '2019-11-30',
#  '2019-12-01',
#  '2019-12-02',
#  '2019-12-03',
#  '2019-12-04',
#  '2019-12-05',
#  '2019-12-06',
#  '2019-12-07',
#  '2019-12-08',
#  '2019-12-09',
#  '2019-12-10',
#  '2019-12-11',
#  '2019-12-12',
#  '2019-12-13',
#  '2019-12-14',
#  '2019-12-15',
#  '2019-12-16',
#  '2019-12-17',
#  '2019-12-18',
#  '2019-12-19',
#  '2019-12-20',
#  '2019-12-21',
#  '2019-12-22',
#  '2019-12-23',
#  '2019-12-24',
#  '2019-12-25',
#  '2019-12-26',
#  '2019-12-27',
#  '2019-12-28',
#  '2019-12-29',
#  '2019-12-30',
#  '2019-12-31',
#  '2020-01-01',
#  '2020-01-02',
#  '2020-01-03',
#  '2020-01-04',
#  '2020-01-05',
#  '2020-01-06',
#  '2020-01-07',
#  '2020-01-08',
#  '2020-01-09',
#  '2020-01-10',
#  '2020-01-11',
#  '2020-01-12',
#  '2020-01-13',
#  '2020-01-14',
#  '2020-01-15',
#  '2020-01-16',
#  '2020-01-17',
#  '2020-01-18',
#  '2020-01-19',
#  '2020-01-20',
#  '2020-01-21',
#  '2020-01-22',
#  '2020-01-23',
#  '2020-01-24',
#  '2020-01-25',
#  '2020-01-26',
#  '2020-01-27',
#  '2020-01-28',
#  '2020-01-29',
#  '2020-01-30',
#  '2020-01-31',
#  '2020-02-01',
#  '2020-02-02',
#  '2020-02-03',
#  '2020-02-04',
#  '2020-02-05',
#  '2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-09',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-02-16',
#  '2020-02-17',
#  '2020-02-18',
#  '2020-02-19',
#  '2020-02-20',
#  '2020-02-21',
#  '2020-02-22',
#  '2020-02-23',
#  '2020-02-24',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-27',
#  '2020-02-28',
#  '2020-02-29',
#  '2020-03-01',
#  '2020-03-02',
#  '2020-03-03',
#  '2020-03-04',
#  '2020-03-05',
#  '2020-03-06',
#  '2020-03-07',
#  '2020-03-08',
#  '2020-03-09',
#  '2020-03-10',
#  '2020-03-11',
#  '2020-03-12',
#  '2020-03-13',
#  '2020-03-14',
#  '2020-03-15',
#  '2020-03-16',
#  '2020-03-17',
#  '2020-03-18',
#  '2020-03-19',
#  '2020-03-20',
#  '2020-03-21',
#  '2020-03-22',
#  '2020-03-23',
#  '2020-03-24',
#  '2020-03-25',
#  '2020-03-26',
#  '2020-03-27',
#  '2020-03-28',
#  '2020-03-29',
#  '2020-03-30',
#  '2020-03-31',
#  '2020-04-01',
#  '2020-04-02',
#  '2020-04-03',
#  '2020-04-04',
#  '2020-04-05',
#  '2020-04-06',
#  '2020-04-07',
#  '2020-04-08',
#  '2020-04-09',
#  '2020-04-10',
#  '2020-04-11',
#  '2020-04-12',
#  '2020-04-13',
#  '2020-04-14',
#  '2020-04-15',
#  '2020-04-16',
#  '2020-04-17',
#  '2020-04-18',
#  '2020-04-19',
#  '2020-04-20',
#  '2020-04-21',
#  '2020-04-22',
#  '2020-04-23',
#  '2020-04-24',
#  '2020-04-25',
#  '2020-04-26',
#  '2020-04-27',
#  '2020-04-28',
#  '2020-04-29',
#  '2020-04-30',
#  '2020-05-01',
#  '2020-05-02',
#  '2020-05-03',
#  '2020-05-04',
#  '2020-05-05',
#  '2020-05-06',
#  '2020-05-07',
#  '2020-05-08',
#  '2020-05-09',
#  '2020-05-10',
#  '2020-05-11',
#  '2020-05-12',
#  '2020-05-13',
#  '2020-05-14',
#  '2020-05-15',
#  '2020-05-16',
#  '2020-05-17',
#  '2020-05-18',
#  '2020-05-19',
#  '2020-05-20',
#  '2020-05-21',
#  '2020-05-22',
#  '2020-05-23',
#  '2020-05-24',
#  '2020-05-25',
#  '2020-05-26',
#  '2020-05-27',
#  '2020-05-28',
#  '2020-05-29',
#  '2020-05-30',
#  '2020-05-31',
#  '2020-06-01',
#  '2020-06-02',
#  '2020-06-03',
#  '2020-06-04',
#  '2020-06-05',
#  '2020-06-06',
#  '2020-06-07',
#  '2020-06-08',
#  '2020-06-09',
#  '2020-06-10',
#  '2020-06-11',
#  '2020-06-12',
#  '2020-06-13',
#  '2020-06-14',
#  '2020-06-15',
#  '2020-06-16',
#  '2020-06-17',
#  '2020-06-18',
#  '2020-06-19',
#  '2020-06-20',
#  '2020-06-21',
#  '2020-06-22',
#  '2020-06-23',
#  '2020-06-24',
#  '2020-06-25',
#  '2020-06-26',
#  '2020-06-27',
#  '2020-06-28',
#  '2020-06-29',
#  '2020-06-30',
#  '2020-07-01',
#  '2020-07-02',
#  '2020-07-03',
#  '2020-07-04',
#  '2020-07-05',
#  '2020-07-06',
#  '2020-07-07',
#  '2020-07-08',
#  '2020-07-09',
#  '2020-07-10',
#  '2020-07-11',
#  '2020-07-12',
#  '2020-07-13',
#  '2020-07-14',
#  '2020-07-15',
#  '2020-07-16',
#  '2020-07-17',
#  '2020-07-18',
#  '2020-07-19',
#  '2020-07-20',
#  '2020-07-21',
#  '2020-07-22',
#  '2020-07-23',
#  '2020-07-24',
#  '2020-07-25',
#  '2020-07-26',
#  '2020-07-27',
#  '2020-07-28',
#  '2020-07-29',
#  '2020-07-30',
#  '2020-07-31',
#  '2020-08-01',
#  '2020-08-02',
#  '2020-08-03',
#  '2020-08-04',
#  '2020-08-05',
#  '2020-08-06',
#  '2020-08-07',
#  '2020-08-08',
#  '2020-08-09',
#  '2020-08-10',
#  '2020-08-11',
#  '2020-08-12',
#  '2020-08-13',
#  '2020-08-14',
#  '2020-08-15',
#  '2020-08-16',
#  '2020-08-17',
#  '2020-08-18',
#  '2020-08-19',
#  '2020-08-20',
#  '2020-08-21',
#  '2020-08-22',
#  '2020-08-23',
#  '2020-08-24',
#  '2020-08-25',
#  '2020-08-26',
#  '2020-08-27',
#  '2020-08-28',
#  '2020-08-29',
#  '2020-08-30',
#  '2020-08-31',
#  '2020-09-01',
#  '2020-09-02',
#  '2020-09-03',
#  '2020-09-04',
#  '2020-09-05',
#  '2020-09-06',
#  '2020-09-07',
#  '2020-09-08',
#  '2020-09-09',
#  '2020-09-10',
#  '2020-09-11']

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(selected)),selected.price)
plt.plot(range(len(selected)),selected.available*100)
plt.show()
